# %%
import matplotlib.pyplot as plt

avgData = [
1,1,1,2,3,2,5,5,11,10,10,13,13,16,20,33,40,44,53,66,60,71,74,79,87,80,86,84,95,98,85,95,90,100,97,103,102,98,109,108,93,100,105,112,94,115,114,116,121,122,112,120,116,122,142,121,136,138,126,150,140,133,142,138,133,144,146,121,131,148,138,150,127,119,140,133,129,138,144,140,137,144,137,137,129,
]
bestData = [
145,145,131,131,132,137,145,141,150,145,145,149,151,151,155,152,169,169,169,152,168,166,166,174,174,182,181,183,186,186,181,186,186,197,197,189,202,202,197,202,191,197,202,197,202,202,202,202,202,202,202,202,202,202,202,202,202,202,202,202,202,202,202,202,202,202,202,202,202,202,202,202,202,202,202,202,202,202,202,202,202,202,202,202,202,
]
sdiData = [
0.44,0.73,0.61,0.79,0.85,0.82,0.92,0.89,0.95,0.95,0.95,0.96,0.97,0.97,0.98,0.99,0.99,0.99,0.99,0.99,0.99,0.99,0.99,0.99,0.99,0.99,0.99,0.99,0.99,0.99,0.99,0.99,0.99,0.99,0.99,0.99,0.99,0.99,0.99,0.99,0.99,0.99,0.99,0.99,0.99,0.99,0.99,0.99,0.99,0.99,0.99,0.99,0.99,0.99,0.99,0.99,0.99,0.99,0.99,0.99,0.99,0.99,0.99,0.99,0.99,0.99,0.99,0.99,0.99,0.99,0.99,0.99,0.99,0.99,0.99,0.99,0.99,0.99,0.99,0.99,0.99,0.99,0.99,0.99,0.99,
]
sdData = [
11,15,12,13,21,16,24,25,34,30,30,33,32,37,38,43,45,45,46,48,50,49,51,54,57,63,63,66,63,67,72,71,74,72,75,74,77,78,77,80,84,84,83,84,89,84,86,87,86,86,90,89,90,89,80,91,85,86,91,79,86,89,85,87,89,84,82,93,90,81,87,80,91,94,86,89,91,87,84,86,88,84,88,88,91,
]

fig, ax1 = plt.subplots()


ax1.set_xlabel('Generationen')
ax1.set_ylabel('Wert')
avg, = ax1.plot(avgData, color='red', label='Avg Werte')
best, = ax1.plot(bestData, color='green', label='Beste Werte')
sda, = ax1.plot(sdData, color='black', label='Standardabweichung')
ax1.tick_params(axis='y')

ax2 = ax1.twinx()

color='blue'
ax2.set_ylabel('Simpsons Diversity Index', color=color)
ax2.plot(sdiData, color=color)
ax2.tick_params(axis='y')

fig.tight_layout()
plt.title('Rucksack Problem')
plt.legend(handles = [avg, best, sda])
plt.show()
